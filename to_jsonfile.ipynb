# %%
import pandas as pd

# Load your CSV into a DataFrame
df = pd.read_csv("path_to_your_csv_file.csv", encoding='utf-8')

# Convert to a JSON file, ensuring that special characters remain unescaped
df.to_json("output_file.json", orient="records", lines=False, force_ascii=False)

print("CSV to JSON conversion completed!")
